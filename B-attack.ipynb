# %%
import os
import torch
from torch.utils.data import DataLoader
from torchvision.utils import save_image, draw_bounding_boxes
from torchvision.ops import box_convert, nms
from torch.nn.functional import interpolate
from PIL import Image
import numpy as np
import torchvision.transforms.functional as TF
from torchvision.transforms import InterpolationMode
from inria_dataloader import get_inria_dataloader
from tmm import load_detr_r50, NestedTensor

# -----------------------
# Config
# -----------------------
ROOT = "/opt/data/private/BlackBox"
SAVE_DIR = os.path.join(ROOT, "save", "attack")
os.makedirs(SAVE_DIR, exist_ok=True)

# Patch params
PATCH_SIDE = 300
MIN_PATCH_PX = 16
SCORE_THRESH = 0.5
IOU_NMS_THRESH = 0.5
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Model input dimensions
MODEL_INPUT_H, MODEL_INPUT_W = 640, 640

# Load trained patch
PATCH_PATH = os.path.join(ROOT, "save", "demo", "final_patch.pt")  # Change path as needed
patch = torch.load(PATCH_PATH)  # [3,H,W] or [1,3,H,W]
if patch.ndimension() == 3:
    patch = patch.unsqueeze(0).to(DEVICE)
else:
    patch = patch.to(DEVICE)

# -----------------------
# Helpers
# -----------------------
def detr_boxes_to_xyxy_pixel(pred_boxes):
    """
    pred_boxes: [Q,4] cx,cy,w,h (normalized 0..1 or absolute)
    returns [Q,4] xyxy in pixel coords (CPU tensor)
    """
    pb = pred_boxes.clone()
    if pb.max() <= 1.01:
        pb[:, 0] = pb[:, 0] * MODEL_INPUT_W
        pb[:, 1] = pb[:, 1] * MODEL_INPUT_H
        pb[:, 2] = pb[:, 2] * MODEL_INPUT_W
        pb[:, 3] = pb[:, 3] * MODEL_INPUT_H
    xyxy = box_convert(pb, in_fmt='cxcywh', out_fmt='xyxy')
    return xyxy.cpu()

def eot_transform_patch(patch_tensor: torch.Tensor):
    """
    patch_tensor: [1,3,H,W] on DEVICE
    apply small random scale / rotate / brightness / contrast
    returns transformed patch [1,3,h2,w2]
    """
    scale = float(np.random.uniform(0.9, 1.1))
    new_side = max(1, int(round(PATCH_SIDE * scale)))
    p = interpolate(patch_tensor, size=(new_side, new_side), mode='bilinear', align_corners=False)
    
    angle = float(np.random.uniform(-10, 10))
    p = TF.affine(p, angle=angle, translate=[0, 0], scale=1.0, shear=[0.0, 0.0], interpolation=InterpolationMode.BILINEAR, fill=0)
    
    b = float(np.random.uniform(0.9, 1.1))
    c = float(np.random.uniform(0.9, 1.1))
    p = torch.clamp((p * c) * b, 0.0, 1.0)
    
    return p

def paste_patch_via_mask(base_img: torch.Tensor, patch_tensor: torch.Tensor, center_xy: tuple):
    """
    base_img: [3,H,W] float on device
    patch_tensor: [1,3,ph,pw] or [3,ph,pw] on same device
    center_xy: (cx, cy) pixel coords (float)
    returns new image [3,H,W] (device) with patch pasted (non-inplace, gradient-preserving)
    """
    if patch_tensor.dim() == 4 and patch_tensor.shape[0] == 1:
        p = patch_tensor[0]
    elif patch_tensor.dim() == 3:
        p = patch_tensor
    else:
        raise ValueError("invalid patch shape")

    ph, pw = p.shape[1], p.shape[2]
    cx, cy = int(round(center_xy[0])), int(round(center_xy[1]))
    x0 = cx - pw // 2
    y0 = cy - ph // 2

    H, W = base_img.shape[1], base_img.shape[2]

    # compute crop ranges
    src_x0, src_y0 = 0, 0
    dst_x0, dst_y0 = x0, y0
    dst_x1, dst_y1 = x0 + pw, y0 + ph

    if dst_x0 < 0:
        src_x0 = -dst_x0; dst_x0 = 0
    if dst_y0 < 0:
        src_y0 = -dst_y0; dst_y0 = 0
    if dst_x1 > W:
        dst_x1 = W
    if dst_y1 > H:
        dst_y1 = H

    out_w = dst_x1 - dst_x0
    out_h = dst_y1 - dst_y0
    if out_w <= 0 or out_h <= 0:
        return base_img.clone()

    src_x1 = src_x0 + out_w
    src_y1 = src_y0 + out_h
    p_cropped = p[:, src_y0:src_y1, src_x0:src_x1]

    # create mask shaped [3,H,W], zeros then set box area to 1
    mask = torch.zeros_like(base_img)
    mask[:, dst_y0:dst_y1, dst_x0:dst_x1] = 1.0

    # build padded_patch with same H,W by padding p_cropped to correct location
    padded_patch = torch.zeros_like(base_img)
    padded_patch[:, dst_y0:dst_y1, dst_x0:dst_x1] = p_cropped

    # fusion (non-inplace)
    fused = base_img * (1.0 - mask) + padded_patch * mask
    return fused

# -----------------------
# Data and model init
# -----------------------
dataloader = get_inria_dataloader("/opt/data/private/BlackBox/data/INRIAPerson", split="Test", batch_size=1, num_workers=4, disable_random_aug=True)
print("Test dataset size:", len(dataloader.dataset))

# Load DETR-R50 model
model = load_detr_r50().to(DEVICE)
model.eval()
for p in model.parameters():
    p.requires_grad = False

# -----------------------
# Attack loop
# -----------------------
for imgs, targets in dataloader:
    imgs = imgs.to(DEVICE).clamp(0, 1)  # shape [B,3,H,W], here B==1
    B = imgs.shape[0]

    # 1) Get detections from clean image using DETR
    with torch.no_grad():
        try:
            det_out = model(imgs)
        except Exception:
            det_out = model(NestedTensor(imgs))

    logits = det_out['pred_logits'][0]  # [Q,C]
    boxes = det_out['pred_boxes'][0]    # [Q,4]
    probs = torch.softmax(logits, dim=-1)
    cls_scores = probs[..., 1]  # person class
    keep_idx = (cls_scores > SCORE_THRESH).nonzero(as_tuple=False).squeeze(1) if (cls_scores > SCORE_THRESH).any() else torch.tensor([], dtype=torch.long, device=cls_scores.device)

    # Convert kept boxes to pixel xyxy
    sel_xyxy = detr_boxes_to_xyxy_pixel(boxes[keep_idx].detach().cpu())  # CPU tensor in pixels

    patched = imgs.clone()

    for box in sel_xyxy:
        xmin, ymin, xmax, ymax = box.tolist()
        box_w = max(int(xmax - xmin), 1)
        box_h = max(int(ymax - ymin), 1)
        short = min(box_w, box_h)
        scale = float(np.clip(short / PATCH_SIDE, 0.5, 2.0))
        side = max(MIN_PATCH_PX, int(round(PATCH_SIDE * scale)))

        # Apply EoT transforms to patch (returns [1,3,side,side])
        patch_to_paste = eot_transform_patch(patch)
        patch_resized = interpolate(patch_to_paste, size=(side, side), mode='bilinear', align_corners=False)
        cx = (xmin + xmax) / 2.0
        cy = (ymin + ymax) / 2.0

        # Fusion (non-inplace, gradient-preserving)
        patched[0] = paste_patch_via_mask(patched[0], patch_resized, center_xy=(cx, cy))

    # Save the patched image
    save_image(patched[0].detach().cpu(), os.path.join(SAVE_DIR, "patched_image.png"))

    # Optionally, run the model on patched image and compute metrics (AP drop, etc.)
    # (not implemented here, but you can compare detection results on patched vs clean)
# Out:
# /tmp/ipykernel_876979/2874604311.py:33: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   patch = torch.load(PATCH_PATH)  # [3,H,W] or [1,3,H,W]
# Using cache found in /root/.cache/torch/hub/facebookresearch_detr_main
# Test dataset size: 288

# %% [markdown]
# # 进一步优化：

# %%
# attack.py
import os
import torch
from torch.utils.data import DataLoader
from torchvision.utils import save_image, draw_bounding_boxes
from torchvision.ops import box_convert, nms
from torch.nn.functional import interpolate
import numpy as np
from inria_dataloader import get_inria_dataloader
from tmm import load_detr_r50, NestedTensor

# -----------------------
# Config
# -----------------------
ROOT = "/opt/data/private/BlackBox"
SAVE_DIR = os.path.join(ROOT, "save", "attack")
os.makedirs(SAVE_DIR, exist_ok=True)

# Patch params
PATCH_SIDE = 300          # 原始 global patch side（训练时基准）
PATCH_RATIO = 0.15        # <<-- 新增：patch 大小 = PATCH_RATIO * target_short_side
MIN_PATCH_PX = 16
SCORE_THRESH = 0.5
IOU_NMS_THRESH = 0.5

# Model / dataset
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_INPUT_H, MODEL_INPUT_W = 640, 640
TARGET_CLASS_IDX = 1   # person class index (与训练一致)
FALLBACK_TO_TOP = True
FALLBACK_SCORE_THRESH = 0.2

# Data loader
BATCH_SIZE = 1
NUM_WORKERS = 4

# Patch path (adjust if needed)
PATCH_PATH = os.path.join(ROOT, "save", "demo", "final_patch.pt")

# -----------------------
# Load patch (safe)
# -----------------------
if not os.path.exists(PATCH_PATH):
    raise FileNotFoundError(f"Patch file not found: {PATCH_PATH}")

patch = torch.load(PATCH_PATH, map_location='cpu')  # load to cpu first
if patch.ndimension() == 3:
    patch = patch.unsqueeze(0)  # [1,3,H,W]
patch = patch.float().to(DEVICE)  # move to device

# Ensure patch in 0..1
patch = patch.clamp(0.0, 1.0)

# -----------------------
# Helpers
# -----------------------
def detr_boxes_to_xyxy_pixel(pred_boxes):
    """
    pred_boxes: [Q,4] cx,cy,w,h (normalized 0..1 or absolute)
    returns [Q,4] xyxy in pixel coords (CPU tensor)
    """
    pb = pred_boxes.clone()
    # if normalized (max <= 1.01), scale to model input dims
    if pb.max() <= 1.01:
        pb[:, 0] = pb[:, 0] * MODEL_INPUT_W
        pb[:, 1] = pb[:, 1] * MODEL_INPUT_H
        pb[:, 2] = pb[:, 2] * MODEL_INPUT_W
        pb[:, 3] = pb[:, 3] * MODEL_INPUT_H
    xyxy = box_convert(pb, in_fmt='cxcywh', out_fmt='xyxy')
    return xyxy.cpu()

def paste_patch_via_mask(base_img: torch.Tensor, patch_tensor: torch.Tensor, center_xy: tuple):
    """
    Paste patch_tensor centered at center_xy into base_img.
    base_img: [3,H,W] (device)
    patch_tensor: [1,3,ph,pw] or [3,ph,pw]
    center_xy: (cx, cy) in pixel coords (float)
    returns new image [3,H,W] (device)
    """
    if patch_tensor.dim() == 4 and patch_tensor.shape[0] == 1:
        p = patch_tensor[0]
    elif patch_tensor.dim() == 3:
        p = patch_tensor
    else:
        raise ValueError("invalid patch shape")

    ph, pw = p.shape[1], p.shape[2]
    cx, cy = int(round(center_xy[0])), int(round(center_xy[1]))
    x0 = cx - pw // 2
    y0 = cy - ph // 2

    H, W = base_img.shape[1], base_img.shape[2]

    # compute crop ranges
    src_x0, src_y0 = 0, 0
    dst_x0, dst_y0 = x0, y0
    dst_x1, dst_y1 = x0 + pw, y0 + ph

    if dst_x0 < 0:
        src_x0 = -dst_x0; dst_x0 = 0
    if dst_y0 < 0:
        src_y0 = -dst_y0; dst_y0 = 0
    if dst_x1 > W:
        dst_x1 = W
    if dst_y1 > H:
        dst_y1 = H

    out_w = dst_x1 - dst_x0
    out_h = dst_y1 - dst_y0
    if out_w <= 0 or out_h <= 0:
        return base_img.clone()

    src_x1 = src_x0 + out_w
    src_y1 = src_y0 + out_h
    p_cropped = p[:, src_y0:src_y1, src_x0:src_x1]

    # create mask shaped [3,H,W], zeros then set box area to 1
    mask = torch.zeros_like(base_img)
    mask[:, dst_y0:dst_y1, dst_x0:dst_x1] = 1.0

    # build padded_patch with same H,W by padding p_cropped to correct location
    padded_patch = torch.zeros_like(base_img)
    padded_patch[:, dst_y0:dst_y1, dst_x0:dst_x1] = p_cropped

    # fusion (non-inplace)
    fused = base_img * (1.0 - mask) + padded_patch * mask
    return fused

def detect_on_image(model, img_tensor):
    """
    Run model on image tensor (shape [1,3,H,W]) and return dict with:
      - logits: [Q,C]
      - boxes: [Q,4] (cx,cy,w,h) normalized or absolute depending on model
      - probs: softmaxed probabilities [Q,C]
    """
    with torch.no_grad():
        try:
            out = model(img_tensor)
        except Exception:
            out = model(NestedTensor(img_tensor))
    logits = out['pred_logits'][0]  # [Q,C]
    boxes = out['pred_boxes'][0]    # [Q,4]
    probs = torch.softmax(logits, dim=-1)
    return {'logits': logits, 'boxes': boxes, 'probs': probs}

# -----------------------
# Data and model init
# -----------------------
dataloader = get_inria_dataloader(os.path.join(ROOT, "data", "INRIAPerson"),
                                  split="Test", batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, disable_random_aug=True)
print("Test dataset size:", len(dataloader.dataset))

# Load DETR-R50 model (white-box)
model = load_detr_r50().to(DEVICE)
model.eval()
for p in model.parameters():
    p.requires_grad = False

# -----------------------
# Attack evaluation loop
# -----------------------
total_images = 0
sum_clean_counts = 0
sum_patched_counts = 0
sum_clean_conf = 0.0
sum_patched_conf = 0.0

for idx, (imgs, targets) in enumerate(dataloader):
    total_images += 1
    imgs = imgs.to(DEVICE).clamp(0, 1)  # [B=1,3,H,W]
    img = imgs  # batch size 1 assumed
    # --- 1) detect on clean image
    clean_out = detect_on_image(model, img)
    logits = clean_out['logits']  # [Q,C]
    boxes = clean_out['boxes']    # [Q,4]
    probs = clean_out['probs']    # [Q,C]
    cls_scores = probs[..., TARGET_CLASS_IDX]  # [Q]

    # select indices above threshold or fallback to top
    if (cls_scores > SCORE_THRESH).any():
        keep_idx = (cls_scores > SCORE_THRESH).nonzero(as_tuple=False).squeeze(1)
    else:
        keep_idx = torch.tensor([], dtype=torch.long, device=cls_scores.device)
        if FALLBACK_TO_TOP:
            top_score, top_idx = torch.max(cls_scores, dim=0)
            if top_score.item() >= FALLBACK_SCORE_THRESH:
                keep_idx = top_idx.unsqueeze(0)

    if keep_idx.numel() == 0:
        sel_xyxy = torch.empty((0,4), dtype=torch.float32)
        sel_scores = torch.empty((0,), dtype=torch.float32)
    else:
        sel_boxes = boxes[keep_idx]
        sel_scores = cls_scores[keep_idx].detach().cpu()
        sel_xyxy = detr_boxes_to_xyxy_pixel(sel_boxes.detach().cpu())  # CPU coords

        # filter by minimum box side (same as train)
        widths = (sel_xyxy[:,2] - sel_xyxy[:,0])
        heights = (sel_xyxy[:,3] - sel_xyxy[:,1])
        large_mask = (widths >= MIN_PATCH_PX) & (heights >= MIN_PATCH_PX)
        if large_mask.sum() == 0:
            sel_xyxy = torch.empty((0,4), dtype=torch.float32)
            sel_scores = torch.empty((0,), dtype=torch.float32)
        else:
            sel_xyxy = sel_xyxy[large_mask]
            sel_scores = sel_scores[large_mask]

            # run NMS (torchvision expects xyxy in float tensors)
            try:
                keep_nms = nms(sel_xyxy, sel_scores, IOU_NMS_THRESH)
            except Exception:
                keep_nms = nms(sel_xyxy.cpu(), sel_scores.cpu(), IOU_NMS_THRESH)
            sel_xyxy = sel_xyxy[keep_nms]
            sel_scores = sel_scores[keep_nms]

    # record clean stats
    clean_count = sel_xyxy.shape[0]
    avg_clean_conf = float(sel_scores.mean().item()) if sel_scores.numel() > 0 else 0.0
    sum_clean_counts += clean_count
    sum_clean_conf += avg_clean_conf

    # --- 2) build patched image (no EoT, no rotation: fixed paste)
    patched = imgs.clone()
    # iterate selected boxes and paste patch centered and scaled
    for b_idx in range(sel_xyxy.shape[0]):
        box = sel_xyxy[b_idx]
        xmin, ymin, xmax, ymax = box.tolist()
        box_w = max(int(xmax - xmin), 1)
        box_h = max(int(ymax - ymin), 1)
        short = min(box_w, box_h)
        # NEW: use PATCH_RATIO relative to short side
        side = max(MIN_PATCH_PX, int(round(PATCH_RATIO * short)))
        # ensure side at least 1
        side = max(1, side)

        # use fixed patch (no EoT / no rotation)
        patch_to_paste = patch
        patch_resized = interpolate(patch_to_paste, size=(side, side), mode='bilinear', align_corners=False)

        cx = (xmin + xmax) / 2.0
        cy = (ymin + ymax) / 2.0

        # paste (non-inplace)
        patched[0] = paste_patch_via_mask(patched[0], patch_resized.to(DEVICE), center_xy=(cx, cy))

    # save patched image (unique filename)
    save_path = os.path.join(SAVE_DIR, f"patched_{idx:04d}.png")
    save_image(patched[0].detach().cpu(), save_path)

    # --- 3) detect on patched image and gather stats
    patched_out = detect_on_image(model, patched)
    p_logits = patched_out['logits']
    p_boxes = patched_out['boxes']
    p_probs = patched_out['probs']
    p_cls_scores = p_probs[..., TARGET_CLASS_IDX]

    if (p_cls_scores > SCORE_THRESH).any():
        p_keep_idx = (p_cls_scores > SCORE_THRESH).nonzero(as_tuple=False).squeeze(1)
    else:
        p_keep_idx = torch.tensor([], dtype=torch.long, device=p_cls_scores.device)
        if FALLBACK_TO_TOP:
            top_score, top_idx = torch.max(p_cls_scores, dim=0)
            if top_score.item() >= FALLBACK_SCORE_THRESH:
                p_keep_idx = top_idx.unsqueeze(0)

    if p_keep_idx.numel() == 0:
        p_sel_xyxy = torch.empty((0,4), dtype=torch.float32)
        p_sel_scores = torch.empty((0,), dtype=torch.float32)
    else:
        p_sel_boxes = p_boxes[p_keep_idx]
        p_sel_scores = p_cls_scores[p_keep_idx].detach().cpu()
        p_sel_xyxy = detr_boxes_to_xyxy_pixel(p_sel_boxes.detach().cpu())

        widths = (p_sel_xyxy[:,2] - p_sel_xyxy[:,0])
        heights = (p_sel_xyxy[:,3] - p_sel_xyxy[:,1])
        large_mask = (widths >= MIN_PATCH_PX) & (heights >= MIN_PATCH_PX)
        if large_mask.sum() == 0:
            p_sel_xyxy = torch.empty((0,4), dtype=torch.float32)
            p_sel_scores = torch.empty((0,), dtype=torch.float32)
        else:
            p_sel_xyxy = p_sel_xyxy[large_mask]
            p_sel_scores = p_sel_scores[large_mask]
            try:
                keep_nms2 = nms(p_sel_xyxy, p_sel_scores, IOU_NMS_THRESH)
            except Exception:
                keep_nms2 = nms(p_sel_xyxy.cpu(), p_sel_scores.cpu(), IOU_NMS_THRESH)
            p_sel_xyxy = p_sel_xyxy[keep_nms2]
            p_sel_scores = p_sel_scores[keep_nms2]

    patched_count = p_sel_xyxy.shape[0]
    avg_patched_conf = float(p_sel_scores.mean().item()) if p_sel_scores.numel() > 0 else 0.0
    sum_patched_counts += patched_count
    sum_patched_conf += avg_patched_conf

    # --- 4) print per-image summary
    print(f"[{idx+1}/{len(dataloader)}] saved {save_path} | clean_count={clean_count} avg_conf={avg_clean_conf:.3f} | patched_count={patched_count} avg_conf={avg_patched_conf:.3f}")

# end loop: summarize
avg_clean = sum_clean_counts / max(1, total_images)
avg_patched = sum_patched_counts / max(1, total_images)
drop_abs = avg_clean - avg_patched
drop_rel = (drop_abs / avg_clean * 100.0) if avg_clean > 0 else 0.0
avg_clean_conf = sum_clean_conf / max(1, total_images)
avg_patched_conf = sum_patched_conf / max(1, total_images)

print("\nAttack summary:")
print(f"  total_images = {total_images}")
print(f"  avg detections (clean)  = {avg_clean:.3f}")
print(f"  avg detections (patched)= {avg_patched:.3f}")
print(f"  absolute drop            = {drop_abs:.3f}")
print(f"  relative drop (%)        = {drop_rel:.2f}%")
print(f"  avg conf (clean)        = {avg_clean_conf:.3f}")
print(f"  avg conf (patched)      = {avg_patched_conf:.3f}")

# done
# Out:
# /tmp/ipykernel_876979/3017179509.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   patch = torch.load(PATCH_PATH, map_location='cpu')  # load to cpu first
# Using cache found in /root/.cache/torch/hub/facebookresearch_detr_main
# Test dataset size: 288
# [1/288] saved /opt/data/private/BlackBox/save/attack/patched_0000.png | clean_count=2 avg_conf=0.994 | patched_count=2 avg_conf=0.992
# [2/288] saved /opt/data/private/BlackBox/save/attack/patched_0001.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.998
# [3/288] saved /opt/data/private/BlackBox/save/attack/patched_0002.png | clean_count=10 avg_conf=0.878 | patched_count=8 avg_conf=0.847
# [4/288] saved /opt/data/private/BlackBox/save/attack/patched_0003.png | clean_count=7 avg_conf=0.970 | patched_count=8 avg_conf=0.892
# [5/288] saved /opt/data/private/BlackBox/save/attack/patched_0004.png | clean_count=1 avg_conf=0.978 | patched_count=1 avg_conf=0.971
# [6/288] saved /opt/data/private/BlackBox/save/attack/patched_0005.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [7/288] saved /opt/data/private/BlackBox/save/attack/patched_0006.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [8/288] saved /opt/data/private/BlackBox/save/attack/patched_0007.png | clean_count=9 avg_conf=0.919 | patched_count=9 avg_conf=0.891
# [9/288] saved /opt/data/private/BlackBox/save/attack/patched_0008.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [10/288] saved /opt/data/private/BlackBox/save/attack/patched_0009.png | clean_count=2 avg_conf=1.000 | patched_count=2 avg_conf=1.000
# [11/288] saved /opt/data/private/BlackBox/save/attack/patched_0010.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.993
# [12/288] saved /opt/data/private/BlackBox/save/attack/patched_0011.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [13/288] saved /opt/data/private/BlackBox/save/attack/patched_0012.png | clean_count=2 avg_conf=0.950 | patched_count=2 avg_conf=0.958
# [14/288] saved /opt/data/private/BlackBox/save/attack/patched_0013.png | clean_count=1 avg_conf=0.964 | patched_count=1 avg_conf=0.993
# [15/288] saved /opt/data/private/BlackBox/save/attack/patched_0014.png | clean_count=1 avg_conf=0.998 | patched_count=1 avg_conf=0.998
# [16/288] saved /opt/data/private/BlackBox/save/attack/patched_0015.png | clean_count=3 avg_conf=0.928 | patched_count=3 avg_conf=0.903
# [17/288] saved /opt/data/private/BlackBox/save/attack/patched_0016.png | clean_count=4 avg_conf=0.983 | patched_count=4 avg_conf=0.994
# [18/288] saved /opt/data/private/BlackBox/save/attack/patched_0017.png | clean_count=1 avg_conf=0.994 | patched_count=1 avg_conf=0.994
# [19/288] saved /opt/data/private/BlackBox/save/attack/patched_0018.png | clean_count=2 avg_conf=0.983 | patched_count=2 avg_conf=0.973
# [20/288] saved /opt/data/private/BlackBox/save/attack/patched_0019.png | clean_count=3 avg_conf=0.999 | patched_count=3 avg_conf=0.999
# [21/288] saved /opt/data/private/BlackBox/save/attack/patched_0020.png | clean_count=5 avg_conf=0.882 | patched_count=3 avg_conf=0.999
# [22/288] saved /opt/data/private/BlackBox/save/attack/patched_0021.png | clean_count=6 avg_conf=0.816 | patched_count=4 avg_conf=0.878
# [23/288] saved /opt/data/private/BlackBox/save/attack/patched_0022.png | clean_count=7 avg_conf=0.995 | patched_count=7 avg_conf=0.989
# [24/288] saved /opt/data/private/BlackBox/save/attack/patched_0023.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [25/288] saved /opt/data/private/BlackBox/save/attack/patched_0024.png | clean_count=14 avg_conf=0.885 | patched_count=10 avg_conf=0.953
# [26/288] saved /opt/data/private/BlackBox/save/attack/patched_0025.png | clean_count=12 avg_conf=0.869 | patched_count=6 avg_conf=0.938
# [27/288] saved /opt/data/private/BlackBox/save/attack/patched_0026.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=0.999
# [28/288] saved /opt/data/private/BlackBox/save/attack/patched_0027.png | clean_count=4 avg_conf=0.934 | patched_count=2 avg_conf=0.979
# [29/288] saved /opt/data/private/BlackBox/save/attack/patched_0028.png | clean_count=1 avg_conf=0.943 | patched_count=1 avg_conf=0.976
# [30/288] saved /opt/data/private/BlackBox/save/attack/patched_0029.png | clean_count=3 avg_conf=0.861 | patched_count=2 avg_conf=1.000
# [31/288] saved /opt/data/private/BlackBox/save/attack/patched_0030.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [32/288] saved /opt/data/private/BlackBox/save/attack/patched_0031.png | clean_count=7 avg_conf=0.794 | patched_count=3 avg_conf=0.878
# [33/288] saved /opt/data/private/BlackBox/save/attack/patched_0032.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.998
# [34/288] saved /opt/data/private/BlackBox/save/attack/patched_0033.png | clean_count=2 avg_conf=1.000 | patched_count=2 avg_conf=1.000
# [35/288] saved /opt/data/private/BlackBox/save/attack/patched_0034.png | clean_count=5 avg_conf=0.762 | patched_count=2 avg_conf=0.752
# [36/288] saved /opt/data/private/BlackBox/save/attack/patched_0035.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [37/288] saved /opt/data/private/BlackBox/save/attack/patched_0036.png | clean_count=6 avg_conf=0.884 | patched_count=4 avg_conf=0.982
# [38/288] saved /opt/data/private/BlackBox/save/attack/patched_0037.png | clean_count=5 avg_conf=0.843 | patched_count=4 avg_conf=0.878
# [39/288] saved /opt/data/private/BlackBox/save/attack/patched_0038.png | clean_count=2 avg_conf=0.898 | patched_count=1 avg_conf=1.000
# [40/288] saved /opt/data/private/BlackBox/save/attack/patched_0039.png | clean_count=3 avg_conf=0.995 | patched_count=3 avg_conf=0.997
# [41/288] saved /opt/data/private/BlackBox/save/attack/patched_0040.png | clean_count=4 avg_conf=0.968 | patched_count=3 avg_conf=0.991
# [42/288] saved /opt/data/private/BlackBox/save/attack/patched_0041.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [43/288] saved /opt/data/private/BlackBox/save/attack/patched_0042.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [44/288] saved /opt/data/private/BlackBox/save/attack/patched_0043.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [45/288] saved /opt/data/private/BlackBox/save/attack/patched_0044.png | clean_count=4 avg_conf=0.881 | patched_count=3 avg_conf=0.912
# [46/288] saved /opt/data/private/BlackBox/save/attack/patched_0045.png | clean_count=1 avg_conf=0.998 | patched_count=1 avg_conf=0.999
# [47/288] saved /opt/data/private/BlackBox/save/attack/patched_0046.png | clean_count=3 avg_conf=0.985 | patched_count=3 avg_conf=0.965
# [48/288] saved /opt/data/private/BlackBox/save/attack/patched_0047.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [49/288] saved /opt/data/private/BlackBox/save/attack/patched_0048.png | clean_count=7 avg_conf=0.902 | patched_count=5 avg_conf=0.915
# [50/288] saved /opt/data/private/BlackBox/save/attack/patched_0049.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [51/288] saved /opt/data/private/BlackBox/save/attack/patched_0050.png | clean_count=3 avg_conf=0.966 | patched_count=3 avg_conf=0.969
# [52/288] saved /opt/data/private/BlackBox/save/attack/patched_0051.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=1.000
# [53/288] saved /opt/data/private/BlackBox/save/attack/patched_0052.png | clean_count=5 avg_conf=0.992 | patched_count=5 avg_conf=0.972
# [54/288] saved /opt/data/private/BlackBox/save/attack/patched_0053.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [55/288] saved /opt/data/private/BlackBox/save/attack/patched_0054.png | clean_count=1 avg_conf=0.987 | patched_count=1 avg_conf=0.981
# [56/288] saved /opt/data/private/BlackBox/save/attack/patched_0055.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [57/288] saved /opt/data/private/BlackBox/save/attack/patched_0056.png | clean_count=2 avg_conf=0.990 | patched_count=2 avg_conf=0.990
# [58/288] saved /opt/data/private/BlackBox/save/attack/patched_0057.png | clean_count=1 avg_conf=0.981 | patched_count=1 avg_conf=0.964
# [59/288] saved /opt/data/private/BlackBox/save/attack/patched_0058.png | clean_count=2 avg_conf=0.722 | patched_count=2 avg_conf=0.743
# [60/288] saved /opt/data/private/BlackBox/save/attack/patched_0059.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [61/288] saved /opt/data/private/BlackBox/save/attack/patched_0060.png | clean_count=6 avg_conf=0.919 | patched_count=6 avg_conf=0.915
# [62/288] saved /opt/data/private/BlackBox/save/attack/patched_0061.png | clean_count=8 avg_conf=0.887 | patched_count=5 avg_conf=0.945
# [63/288] saved /opt/data/private/BlackBox/save/attack/patched_0062.png | clean_count=5 avg_conf=0.911 | patched_count=3 avg_conf=0.998
# [64/288] saved /opt/data/private/BlackBox/save/attack/patched_0063.png | clean_count=3 avg_conf=0.999 | patched_count=3 avg_conf=0.999
# [65/288] saved /opt/data/private/BlackBox/save/attack/patched_0064.png | clean_count=5 avg_conf=0.998 | patched_count=5 avg_conf=0.998
# [66/288] saved /opt/data/private/BlackBox/save/attack/patched_0065.png | clean_count=5 avg_conf=0.872 | patched_count=3 avg_conf=0.905
# [67/288] saved /opt/data/private/BlackBox/save/attack/patched_0066.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [68/288] saved /opt/data/private/BlackBox/save/attack/patched_0067.png | clean_count=1 avg_conf=0.998 | patched_count=1 avg_conf=0.999
# [69/288] saved /opt/data/private/BlackBox/save/attack/patched_0068.png | clean_count=11 avg_conf=0.850 | patched_count=6 avg_conf=0.876
# [70/288] saved /opt/data/private/BlackBox/save/attack/patched_0069.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [71/288] saved /opt/data/private/BlackBox/save/attack/patched_0070.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [72/288] saved /opt/data/private/BlackBox/save/attack/patched_0071.png | clean_count=13 avg_conf=0.844 | patched_count=13 avg_conf=0.835
# [73/288] saved /opt/data/private/BlackBox/save/attack/patched_0072.png | clean_count=10 avg_conf=0.786 | patched_count=3 avg_conf=0.999
# [74/288] saved /opt/data/private/BlackBox/save/attack/patched_0073.png | clean_count=1 avg_conf=0.996 | patched_count=1 avg_conf=0.996
# [75/288] saved /opt/data/private/BlackBox/save/attack/patched_0074.png | clean_count=2 avg_conf=0.999 | patched_count=2 avg_conf=0.999
# [76/288] saved /opt/data/private/BlackBox/save/attack/patched_0075.png | clean_count=3 avg_conf=0.842 | patched_count=1 avg_conf=0.999
# [77/288] saved /opt/data/private/BlackBox/save/attack/patched_0076.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [78/288] saved /opt/data/private/BlackBox/save/attack/patched_0077.png | clean_count=3 avg_conf=0.980 | patched_count=3 avg_conf=0.987
# [79/288] saved /opt/data/private/BlackBox/save/attack/patched_0078.png | clean_count=8 avg_conf=0.908 | patched_count=5 avg_conf=0.927
# [80/288] saved /opt/data/private/BlackBox/save/attack/patched_0079.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [81/288] saved /opt/data/private/BlackBox/save/attack/patched_0080.png | clean_count=8 avg_conf=0.874 | patched_count=7 avg_conf=0.833
# [82/288] saved /opt/data/private/BlackBox/save/attack/patched_0081.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [83/288] saved /opt/data/private/BlackBox/save/attack/patched_0082.png | clean_count=4 avg_conf=0.953 | patched_count=3 avg_conf=0.998
# [84/288] saved /opt/data/private/BlackBox/save/attack/patched_0083.png | clean_count=2 avg_conf=0.889 | patched_count=1 avg_conf=0.999
# [85/288] saved /opt/data/private/BlackBox/save/attack/patched_0084.png | clean_count=15 avg_conf=0.880 | patched_count=8 avg_conf=0.841
# [86/288] saved /opt/data/private/BlackBox/save/attack/patched_0085.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [87/288] saved /opt/data/private/BlackBox/save/attack/patched_0086.png | clean_count=1 avg_conf=0.995 | patched_count=1 avg_conf=0.996
# [88/288] saved /opt/data/private/BlackBox/save/attack/patched_0087.png | clean_count=16 avg_conf=0.823 | patched_count=18 avg_conf=0.768
# [89/288] saved /opt/data/private/BlackBox/save/attack/patched_0088.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=0.999
# [90/288] saved /opt/data/private/BlackBox/save/attack/patched_0089.png | clean_count=7 avg_conf=0.953 | patched_count=6 avg_conf=0.995
# [91/288] saved /opt/data/private/BlackBox/save/attack/patched_0090.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [92/288] saved /opt/data/private/BlackBox/save/attack/patched_0091.png | clean_count=2 avg_conf=0.999 | patched_count=2 avg_conf=0.999
# [93/288] saved /opt/data/private/BlackBox/save/attack/patched_0092.png | clean_count=2 avg_conf=0.999 | patched_count=2 avg_conf=0.999
# [94/288] saved /opt/data/private/BlackBox/save/attack/patched_0093.png | clean_count=14 avg_conf=0.775 | patched_count=5 avg_conf=0.837
# [95/288] saved /opt/data/private/BlackBox/save/attack/patched_0094.png | clean_count=2 avg_conf=0.997 | patched_count=2 avg_conf=0.994
# [96/288] saved /opt/data/private/BlackBox/save/attack/patched_0095.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [97/288] saved /opt/data/private/BlackBox/save/attack/patched_0096.png | clean_count=3 avg_conf=0.908 | patched_count=2 avg_conf=0.999
# [98/288] saved /opt/data/private/BlackBox/save/attack/patched_0097.png | clean_count=4 avg_conf=0.971 | patched_count=4 avg_conf=0.946
# [99/288] saved /opt/data/private/BlackBox/save/attack/patched_0098.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [100/288] saved /opt/data/private/BlackBox/save/attack/patched_0099.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [101/288] saved /opt/data/private/BlackBox/save/attack/patched_0100.png | clean_count=2 avg_conf=0.999 | patched_count=2 avg_conf=0.999
# [102/288] saved /opt/data/private/BlackBox/save/attack/patched_0101.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [103/288] saved /opt/data/private/BlackBox/save/attack/patched_0102.png | clean_count=2 avg_conf=0.998 | patched_count=2 avg_conf=0.998
# [104/288] saved /opt/data/private/BlackBox/save/attack/patched_0103.png | clean_count=2 avg_conf=0.952 | patched_count=2 avg_conf=0.911
# [105/288] saved /opt/data/private/BlackBox/save/attack/patched_0104.png | clean_count=2 avg_conf=0.793 | patched_count=1 avg_conf=1.000
# [106/288] saved /opt/data/private/BlackBox/save/attack/patched_0105.png | clean_count=3 avg_conf=0.876 | patched_count=2 avg_conf=0.999
# [107/288] saved /opt/data/private/BlackBox/save/attack/patched_0106.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [108/288] saved /opt/data/private/BlackBox/save/attack/patched_0107.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [109/288] saved /opt/data/private/BlackBox/save/attack/patched_0108.png | clean_count=6 avg_conf=0.917 | patched_count=5 avg_conf=0.971
# [110/288] saved /opt/data/private/BlackBox/save/attack/patched_0109.png | clean_count=2 avg_conf=0.842 | patched_count=1 avg_conf=1.000
# [111/288] saved /opt/data/private/BlackBox/save/attack/patched_0110.png | clean_count=2 avg_conf=1.000 | patched_count=2 avg_conf=1.000
# [112/288] saved /opt/data/private/BlackBox/save/attack/patched_0111.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [113/288] saved /opt/data/private/BlackBox/save/attack/patched_0112.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [114/288] saved /opt/data/private/BlackBox/save/attack/patched_0113.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [115/288] saved /opt/data/private/BlackBox/save/attack/patched_0114.png | clean_count=16 avg_conf=0.864 | patched_count=10 avg_conf=0.913
# [116/288] saved /opt/data/private/BlackBox/save/attack/patched_0115.png | clean_count=5 avg_conf=0.681 | patched_count=2 avg_conf=0.827
# [117/288] saved /opt/data/private/BlackBox/save/attack/patched_0116.png | clean_count=8 avg_conf=0.950 | patched_count=8 avg_conf=0.921
# [118/288] saved /opt/data/private/BlackBox/save/attack/patched_0117.png | clean_count=2 avg_conf=0.991 | patched_count=2 avg_conf=0.976
# [119/288] saved /opt/data/private/BlackBox/save/attack/patched_0118.png | clean_count=1 avg_conf=0.975 | patched_count=1 avg_conf=0.961
# [120/288] saved /opt/data/private/BlackBox/save/attack/patched_0119.png | clean_count=3 avg_conf=0.906 | patched_count=2 avg_conf=0.999
# [121/288] saved /opt/data/private/BlackBox/save/attack/patched_0120.png | clean_count=1 avg_conf=0.998 | patched_count=1 avg_conf=0.998
# [122/288] saved /opt/data/private/BlackBox/save/attack/patched_0121.png | clean_count=4 avg_conf=0.999 | patched_count=4 avg_conf=0.999
# [123/288] saved /opt/data/private/BlackBox/save/attack/patched_0122.png | clean_count=1 avg_conf=0.993 | patched_count=1 avg_conf=0.993
# [124/288] saved /opt/data/private/BlackBox/save/attack/patched_0123.png | clean_count=2 avg_conf=0.840 | patched_count=1 avg_conf=1.000
# [125/288] saved /opt/data/private/BlackBox/save/attack/patched_0124.png | clean_count=2 avg_conf=0.991 | patched_count=2 avg_conf=0.993
# [126/288] saved /opt/data/private/BlackBox/save/attack/patched_0125.png | clean_count=16 avg_conf=0.879 | patched_count=16 avg_conf=0.790
# [127/288] saved /opt/data/private/BlackBox/save/attack/patched_0126.png | clean_count=1 avg_conf=0.991 | patched_count=1 avg_conf=0.988
# [128/288] saved /opt/data/private/BlackBox/save/attack/patched_0127.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [129/288] saved /opt/data/private/BlackBox/save/attack/patched_0128.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [130/288] saved /opt/data/private/BlackBox/save/attack/patched_0129.png | clean_count=2 avg_conf=0.979 | patched_count=2 avg_conf=0.973
# [131/288] saved /opt/data/private/BlackBox/save/attack/patched_0130.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [132/288] saved /opt/data/private/BlackBox/save/attack/patched_0131.png | clean_count=2 avg_conf=0.999 | patched_count=2 avg_conf=0.999
# [133/288] saved /opt/data/private/BlackBox/save/attack/patched_0132.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [134/288] saved /opt/data/private/BlackBox/save/attack/patched_0133.png | clean_count=1 avg_conf=0.936 | patched_count=1 avg_conf=0.962
# [135/288] saved /opt/data/private/BlackBox/save/attack/patched_0134.png | clean_count=18 avg_conf=0.849 | patched_count=9 avg_conf=0.955
# [136/288] saved /opt/data/private/BlackBox/save/attack/patched_0135.png | clean_count=19 avg_conf=0.759 | patched_count=12 avg_conf=0.852
# [137/288] saved /opt/data/private/BlackBox/save/attack/patched_0136.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=1.000
# [138/288] saved /opt/data/private/BlackBox/save/attack/patched_0137.png | clean_count=9 avg_conf=0.884 | patched_count=6 avg_conf=0.990
# [139/288] saved /opt/data/private/BlackBox/save/attack/patched_0138.png | clean_count=1 avg_conf=0.918 | patched_count=0 avg_conf=0.000
# [140/288] saved /opt/data/private/BlackBox/save/attack/patched_0139.png | clean_count=5 avg_conf=0.852 | patched_count=2 avg_conf=0.999
# [141/288] saved /opt/data/private/BlackBox/save/attack/patched_0140.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [142/288] saved /opt/data/private/BlackBox/save/attack/patched_0141.png | clean_count=5 avg_conf=0.856 | patched_count=4 avg_conf=0.966
# [143/288] saved /opt/data/private/BlackBox/save/attack/patched_0142.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [144/288] saved /opt/data/private/BlackBox/save/attack/patched_0143.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [145/288] saved /opt/data/private/BlackBox/save/attack/patched_0144.png | clean_count=2 avg_conf=0.995 | patched_count=2 avg_conf=0.998
# [146/288] saved /opt/data/private/BlackBox/save/attack/patched_0145.png | clean_count=8 avg_conf=0.885 | patched_count=6 avg_conf=0.826
# [147/288] saved /opt/data/private/BlackBox/save/attack/patched_0146.png | clean_count=9 avg_conf=0.818 | patched_count=5 avg_conf=0.896
# [148/288] saved /opt/data/private/BlackBox/save/attack/patched_0147.png | clean_count=7 avg_conf=0.876 | patched_count=6 avg_conf=0.950
# [149/288] saved /opt/data/private/BlackBox/save/attack/patched_0148.png | clean_count=5 avg_conf=0.903 | patched_count=5 avg_conf=0.912
# [150/288] saved /opt/data/private/BlackBox/save/attack/patched_0149.png | clean_count=1 avg_conf=0.998 | patched_count=1 avg_conf=0.998
# [151/288] saved /opt/data/private/BlackBox/save/attack/patched_0150.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [152/288] saved /opt/data/private/BlackBox/save/attack/patched_0151.png | clean_count=12 avg_conf=0.891 | patched_count=9 avg_conf=0.935
# [153/288] saved /opt/data/private/BlackBox/save/attack/patched_0152.png | clean_count=3 avg_conf=0.999 | patched_count=3 avg_conf=0.999
# [154/288] saved /opt/data/private/BlackBox/save/attack/patched_0153.png | clean_count=4 avg_conf=0.860 | patched_count=3 avg_conf=0.954
# [155/288] saved /opt/data/private/BlackBox/save/attack/patched_0154.png | clean_count=7 avg_conf=0.828 | patched_count=4 avg_conf=0.896
# [156/288] saved /opt/data/private/BlackBox/save/attack/patched_0155.png | clean_count=7 avg_conf=0.891 | patched_count=6 avg_conf=0.920
# [157/288] saved /opt/data/private/BlackBox/save/attack/patched_0156.png | clean_count=1 avg_conf=0.998 | patched_count=1 avg_conf=0.998
# [158/288] saved /opt/data/private/BlackBox/save/attack/patched_0157.png | clean_count=1 avg_conf=0.985 | patched_count=1 avg_conf=0.994
# [159/288] saved /opt/data/private/BlackBox/save/attack/patched_0158.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [160/288] saved /opt/data/private/BlackBox/save/attack/patched_0159.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [161/288] saved /opt/data/private/BlackBox/save/attack/patched_0160.png | clean_count=2 avg_conf=0.950 | patched_count=1 avg_conf=1.000
# [162/288] saved /opt/data/private/BlackBox/save/attack/patched_0161.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.998
# [163/288] saved /opt/data/private/BlackBox/save/attack/patched_0162.png | clean_count=5 avg_conf=0.799 | patched_count=3 avg_conf=0.854
# [164/288] saved /opt/data/private/BlackBox/save/attack/patched_0163.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [165/288] saved /opt/data/private/BlackBox/save/attack/patched_0164.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=0.999
# [166/288] saved /opt/data/private/BlackBox/save/attack/patched_0165.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [167/288] saved /opt/data/private/BlackBox/save/attack/patched_0166.png | clean_count=4 avg_conf=0.991 | patched_count=4 avg_conf=0.981
# [168/288] saved /opt/data/private/BlackBox/save/attack/patched_0167.png | clean_count=4 avg_conf=0.966 | patched_count=4 avg_conf=0.961
# [169/288] saved /opt/data/private/BlackBox/save/attack/patched_0168.png | clean_count=1 avg_conf=0.998 | patched_count=1 avg_conf=0.998
# [170/288] saved /opt/data/private/BlackBox/save/attack/patched_0169.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [171/288] saved /opt/data/private/BlackBox/save/attack/patched_0170.png | clean_count=3 avg_conf=0.998 | patched_count=3 avg_conf=0.998
# [172/288] saved /opt/data/private/BlackBox/save/attack/patched_0171.png | clean_count=1 avg_conf=0.973 | patched_count=1 avg_conf=0.972
# [173/288] saved /opt/data/private/BlackBox/save/attack/patched_0172.png | clean_count=1 avg_conf=0.998 | patched_count=1 avg_conf=0.998
# [174/288] saved /opt/data/private/BlackBox/save/attack/patched_0173.png | clean_count=2 avg_conf=0.999 | patched_count=2 avg_conf=0.999
# [175/288] saved /opt/data/private/BlackBox/save/attack/patched_0174.png | clean_count=2 avg_conf=0.788 | patched_count=2 avg_conf=0.968
# [176/288] saved /opt/data/private/BlackBox/save/attack/patched_0175.png | clean_count=2 avg_conf=1.000 | patched_count=2 avg_conf=1.000
# [177/288] saved /opt/data/private/BlackBox/save/attack/patched_0176.png | clean_count=1 avg_conf=0.996 | patched_count=1 avg_conf=0.999
# [178/288] saved /opt/data/private/BlackBox/save/attack/patched_0177.png | clean_count=11 avg_conf=0.897 | patched_count=9 avg_conf=0.843
# [179/288] saved /opt/data/private/BlackBox/save/attack/patched_0178.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [180/288] saved /opt/data/private/BlackBox/save/attack/patched_0179.png | clean_count=1 avg_conf=0.931 | patched_count=1 avg_conf=0.946
# [181/288] saved /opt/data/private/BlackBox/save/attack/patched_0180.png | clean_count=2 avg_conf=0.998 | patched_count=2 avg_conf=0.997
# [182/288] saved /opt/data/private/BlackBox/save/attack/patched_0181.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [183/288] saved /opt/data/private/BlackBox/save/attack/patched_0182.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [184/288] saved /opt/data/private/BlackBox/save/attack/patched_0183.png | clean_count=2 avg_conf=0.999 | patched_count=2 avg_conf=0.999
# [185/288] saved /opt/data/private/BlackBox/save/attack/patched_0184.png | clean_count=7 avg_conf=0.904 | patched_count=4 avg_conf=0.990
# [186/288] saved /opt/data/private/BlackBox/save/attack/patched_0185.png | clean_count=26 avg_conf=0.769 | patched_count=21 avg_conf=0.805
# [187/288] saved /opt/data/private/BlackBox/save/attack/patched_0186.png | clean_count=4 avg_conf=0.850 | patched_count=1 avg_conf=0.999
# [188/288] saved /opt/data/private/BlackBox/save/attack/patched_0187.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [189/288] saved /opt/data/private/BlackBox/save/attack/patched_0188.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [190/288] saved /opt/data/private/BlackBox/save/attack/patched_0189.png | clean_count=2 avg_conf=0.997 | patched_count=2 avg_conf=0.998
# [191/288] saved /opt/data/private/BlackBox/save/attack/patched_0190.png | clean_count=1 avg_conf=0.993 | patched_count=1 avg_conf=0.997
# [192/288] saved /opt/data/private/BlackBox/save/attack/patched_0191.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [193/288] saved /opt/data/private/BlackBox/save/attack/patched_0192.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [194/288] saved /opt/data/private/BlackBox/save/attack/patched_0193.png | clean_count=1 avg_conf=0.970 | patched_count=1 avg_conf=0.989
# [195/288] saved /opt/data/private/BlackBox/save/attack/patched_0194.png | clean_count=2 avg_conf=1.000 | patched_count=3 avg_conf=0.935
# [196/288] saved /opt/data/private/BlackBox/save/attack/patched_0195.png | clean_count=2 avg_conf=0.790 | patched_count=2 avg_conf=0.809
# [197/288] saved /opt/data/private/BlackBox/save/attack/patched_0196.png | clean_count=4 avg_conf=0.872 | patched_count=3 avg_conf=0.833
# [198/288] saved /opt/data/private/BlackBox/save/attack/patched_0197.png | clean_count=1 avg_conf=0.906 | patched_count=1 avg_conf=0.887
# [199/288] saved /opt/data/private/BlackBox/save/attack/patched_0198.png | clean_count=16 avg_conf=0.788 | patched_count=9 avg_conf=0.803
# [200/288] saved /opt/data/private/BlackBox/save/attack/patched_0199.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [201/288] saved /opt/data/private/BlackBox/save/attack/patched_0200.png | clean_count=3 avg_conf=0.865 | patched_count=2 avg_conf=0.999
# [202/288] saved /opt/data/private/BlackBox/save/attack/patched_0201.png | clean_count=3 avg_conf=0.857 | patched_count=2 avg_conf=0.999
# [203/288] saved /opt/data/private/BlackBox/save/attack/patched_0202.png | clean_count=3 avg_conf=0.832 | patched_count=2 avg_conf=0.995
# [204/288] saved /opt/data/private/BlackBox/save/attack/patched_0203.png | clean_count=9 avg_conf=0.896 | patched_count=8 avg_conf=0.939
# [205/288] saved /opt/data/private/BlackBox/save/attack/patched_0204.png | clean_count=1 avg_conf=0.998 | patched_count=1 avg_conf=0.998
# [206/288] saved /opt/data/private/BlackBox/save/attack/patched_0205.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [207/288] saved /opt/data/private/BlackBox/save/attack/patched_0206.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [208/288] saved /opt/data/private/BlackBox/save/attack/patched_0207.png | clean_count=17 avg_conf=0.849 | patched_count=12 avg_conf=0.867
# [209/288] saved /opt/data/private/BlackBox/save/attack/patched_0208.png | clean_count=1 avg_conf=0.998 | patched_count=1 avg_conf=0.998
# [210/288] saved /opt/data/private/BlackBox/save/attack/patched_0209.png | clean_count=3 avg_conf=0.899 | patched_count=3 avg_conf=0.834
# [211/288] saved /opt/data/private/BlackBox/save/attack/patched_0210.png | clean_count=5 avg_conf=0.995 | patched_count=5 avg_conf=0.993
# [212/288] saved /opt/data/private/BlackBox/save/attack/patched_0211.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=1.000
# [213/288] saved /opt/data/private/BlackBox/save/attack/patched_0212.png | clean_count=4 avg_conf=0.748 | patched_count=1 avg_conf=1.000
# [214/288] saved /opt/data/private/BlackBox/save/attack/patched_0213.png | clean_count=8 avg_conf=0.804 | patched_count=7 avg_conf=0.850
# [215/288] saved /opt/data/private/BlackBox/save/attack/patched_0214.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [216/288] saved /opt/data/private/BlackBox/save/attack/patched_0215.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [217/288] saved /opt/data/private/BlackBox/save/attack/patched_0216.png | clean_count=3 avg_conf=0.999 | patched_count=3 avg_conf=0.999
# [218/288] saved /opt/data/private/BlackBox/save/attack/patched_0217.png | clean_count=16 avg_conf=0.922 | patched_count=17 avg_conf=0.909
# [219/288] saved /opt/data/private/BlackBox/save/attack/patched_0218.png | clean_count=5 avg_conf=0.924 | patched_count=4 avg_conf=0.997
# [220/288] saved /opt/data/private/BlackBox/save/attack/patched_0219.png | clean_count=3 avg_conf=0.859 | patched_count=2 avg_conf=0.999
# [221/288] saved /opt/data/private/BlackBox/save/attack/patched_0220.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.998
# [222/288] saved /opt/data/private/BlackBox/save/attack/patched_0221.png | clean_count=15 avg_conf=0.825 | patched_count=6 avg_conf=0.836
# [223/288] saved /opt/data/private/BlackBox/save/attack/patched_0222.png | clean_count=13 avg_conf=0.880 | patched_count=13 avg_conf=0.837
# [224/288] saved /opt/data/private/BlackBox/save/attack/patched_0223.png | clean_count=3 avg_conf=0.946 | patched_count=2 avg_conf=0.994
# [225/288] saved /opt/data/private/BlackBox/save/attack/patched_0224.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [226/288] saved /opt/data/private/BlackBox/save/attack/patched_0225.png | clean_count=17 avg_conf=0.812 | patched_count=9 avg_conf=0.922
# [227/288] saved /opt/data/private/BlackBox/save/attack/patched_0226.png | clean_count=17 avg_conf=0.830 | patched_count=14 avg_conf=0.796
# [228/288] saved /opt/data/private/BlackBox/save/attack/patched_0227.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [229/288] saved /opt/data/private/BlackBox/save/attack/patched_0228.png | clean_count=1 avg_conf=0.996 | patched_count=1 avg_conf=0.998
# [230/288] saved /opt/data/private/BlackBox/save/attack/patched_0229.png | clean_count=7 avg_conf=0.848 | patched_count=4 avg_conf=0.882
# [231/288] saved /opt/data/private/BlackBox/save/attack/patched_0230.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [232/288] saved /opt/data/private/BlackBox/save/attack/patched_0231.png | clean_count=9 avg_conf=0.915 | patched_count=9 avg_conf=0.889
# [233/288] saved /opt/data/private/BlackBox/save/attack/patched_0232.png | clean_count=2 avg_conf=0.824 | patched_count=2 avg_conf=0.804
# [234/288] saved /opt/data/private/BlackBox/save/attack/patched_0233.png | clean_count=5 avg_conf=0.866 | patched_count=3 avg_conf=0.989
# [235/288] saved /opt/data/private/BlackBox/save/attack/patched_0234.png | clean_count=5 avg_conf=0.998 | patched_count=6 avg_conf=0.930
# [236/288] saved /opt/data/private/BlackBox/save/attack/patched_0235.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [237/288] saved /opt/data/private/BlackBox/save/attack/patched_0236.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [238/288] saved /opt/data/private/BlackBox/save/attack/patched_0237.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [239/288] saved /opt/data/private/BlackBox/save/attack/patched_0238.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [240/288] saved /opt/data/private/BlackBox/save/attack/patched_0239.png | clean_count=22 avg_conf=0.741 | patched_count=7 avg_conf=0.887
# [241/288] saved /opt/data/private/BlackBox/save/attack/patched_0240.png | clean_count=3 avg_conf=0.820 | patched_count=1 avg_conf=0.996
# [242/288] saved /opt/data/private/BlackBox/save/attack/patched_0241.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [243/288] saved /opt/data/private/BlackBox/save/attack/patched_0242.png | clean_count=2 avg_conf=0.999 | patched_count=2 avg_conf=0.999
# [244/288] saved /opt/data/private/BlackBox/save/attack/patched_0243.png | clean_count=7 avg_conf=0.910 | patched_count=8 avg_conf=0.754
# [245/288] saved /opt/data/private/BlackBox/save/attack/patched_0244.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=0.999
# [246/288] saved /opt/data/private/BlackBox/save/attack/patched_0245.png | clean_count=5 avg_conf=0.973 | patched_count=5 avg_conf=0.905
# [247/288] saved /opt/data/private/BlackBox/save/attack/patched_0246.png | clean_count=2 avg_conf=0.999 | patched_count=2 avg_conf=0.999
# [248/288] saved /opt/data/private/BlackBox/save/attack/patched_0247.png | clean_count=2 avg_conf=0.999 | patched_count=2 avg_conf=0.999
# [249/288] saved /opt/data/private/BlackBox/save/attack/patched_0248.png | clean_count=1 avg_conf=0.998 | patched_count=1 avg_conf=0.999
# [250/288] saved /opt/data/private/BlackBox/save/attack/patched_0249.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [251/288] saved /opt/data/private/BlackBox/save/attack/patched_0250.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [252/288] saved /opt/data/private/BlackBox/save/attack/patched_0251.png | clean_count=3 avg_conf=0.997 | patched_count=3 avg_conf=0.999
# [253/288] saved /opt/data/private/BlackBox/save/attack/patched_0252.png | clean_count=4 avg_conf=0.999 | patched_count=4 avg_conf=0.999
# [254/288] saved /opt/data/private/BlackBox/save/attack/patched_0253.png | clean_count=2 avg_conf=0.999 | patched_count=2 avg_conf=0.998
# [255/288] saved /opt/data/private/BlackBox/save/attack/patched_0254.png | clean_count=2 avg_conf=0.979 | patched_count=2 avg_conf=0.969
# [256/288] saved /opt/data/private/BlackBox/save/attack/patched_0255.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [257/288] saved /opt/data/private/BlackBox/save/attack/patched_0256.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [258/288] saved /opt/data/private/BlackBox/save/attack/patched_0257.png | clean_count=2 avg_conf=0.975 | patched_count=1 avg_conf=0.999
# [259/288] saved /opt/data/private/BlackBox/save/attack/patched_0258.png | clean_count=2 avg_conf=1.000 | patched_count=2 avg_conf=1.000
# [260/288] saved /opt/data/private/BlackBox/save/attack/patched_0259.png | clean_count=1 avg_conf=0.985 | patched_count=1 avg_conf=0.987
# [261/288] saved /opt/data/private/BlackBox/save/attack/patched_0260.png | clean_count=9 avg_conf=0.942 | patched_count=8 avg_conf=0.947
# [262/288] saved /opt/data/private/BlackBox/save/attack/patched_0261.png | clean_count=2 avg_conf=0.996 | patched_count=2 avg_conf=0.994
# [263/288] saved /opt/data/private/BlackBox/save/attack/patched_0262.png | clean_count=10 avg_conf=0.828 | patched_count=2 avg_conf=1.000
# [264/288] saved /opt/data/private/BlackBox/save/attack/patched_0263.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [265/288] saved /opt/data/private/BlackBox/save/attack/patched_0264.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [266/288] saved /opt/data/private/BlackBox/save/attack/patched_0265.png | clean_count=3 avg_conf=0.999 | patched_count=3 avg_conf=0.999
# [267/288] saved /opt/data/private/BlackBox/save/attack/patched_0266.png | clean_count=13 avg_conf=0.800 | patched_count=7 avg_conf=0.867
# [268/288] saved /opt/data/private/BlackBox/save/attack/patched_0267.png | clean_count=6 avg_conf=0.998 | patched_count=6 avg_conf=0.998
# [269/288] saved /opt/data/private/BlackBox/save/attack/patched_0268.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [270/288] saved /opt/data/private/BlackBox/save/attack/patched_0269.png | clean_count=1 avg_conf=0.998 | patched_count=1 avg_conf=0.998
# [271/288] saved /opt/data/private/BlackBox/save/attack/patched_0270.png | clean_count=4 avg_conf=0.870 | patched_count=3 avg_conf=0.986
# [272/288] saved /opt/data/private/BlackBox/save/attack/patched_0271.png | clean_count=4 avg_conf=0.744 | patched_count=3 avg_conf=0.794
# [273/288] saved /opt/data/private/BlackBox/save/attack/patched_0272.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [274/288] saved /opt/data/private/BlackBox/save/attack/patched_0273.png | clean_count=3 avg_conf=0.860 | patched_count=1 avg_conf=1.000
# [275/288] saved /opt/data/private/BlackBox/save/attack/patched_0274.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [276/288] saved /opt/data/private/BlackBox/save/attack/patched_0275.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [277/288] saved /opt/data/private/BlackBox/save/attack/patched_0276.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [278/288] saved /opt/data/private/BlackBox/save/attack/patched_0277.png | clean_count=6 avg_conf=0.829 | patched_count=3 avg_conf=0.879
# [279/288] saved /opt/data/private/BlackBox/save/attack/patched_0278.png | clean_count=2 avg_conf=0.707 | patched_count=2 avg_conf=0.713
# [280/288] saved /opt/data/private/BlackBox/save/attack/patched_0279.png | clean_count=5 avg_conf=0.834 | patched_count=2 avg_conf=1.000
# [281/288] saved /opt/data/private/BlackBox/save/attack/patched_0280.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [282/288] saved /opt/data/private/BlackBox/save/attack/patched_0281.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [283/288] saved /opt/data/private/BlackBox/save/attack/patched_0282.png | clean_count=1 avg_conf=0.999 | patched_count=1 avg_conf=0.999
# [284/288] saved /opt/data/private/BlackBox/save/attack/patched_0283.png | clean_count=4 avg_conf=0.999 | patched_count=4 avg_conf=0.999
# [285/288] saved /opt/data/private/BlackBox/save/attack/patched_0284.png | clean_count=1 avg_conf=0.964 | patched_count=1 avg_conf=0.990
# [286/288] saved /opt/data/private/BlackBox/save/attack/patched_0285.png | clean_count=4 avg_conf=0.970 | patched_count=5 avg_conf=0.881
# [287/288] saved /opt/data/private/BlackBox/save/attack/patched_0286.png | clean_count=1 avg_conf=1.000 | patched_count=1 avg_conf=1.000
# [288/288] saved /opt/data/private/BlackBox/save/attack/patched_0287.png | clean_count=4 avg_conf=0.952 | patched_count=5 avg_conf=0.912
#
# Attack summary:
#   total_images = 288
#   avg detections (clean)  = 3.681
#   avg detections (patched)= 2.875
#   absolute drop            = 0.806
#   relative drop (%)        = 21.89%
#   avg conf (clean)        = 0.946
#   avg conf (patched)      = 0.962

# %% [markdown]
# # 添加返回recall功能：

# %%
# attack_with_recall.py
import os
import torch
from torch.utils.data import DataLoader
from torchvision.utils import save_image
from torchvision.ops import box_convert, nms
from torch.nn.functional import interpolate
import numpy as np
from inria_dataloader import get_inria_dataloader
from tmm import load_detr_r50, NestedTensor

# -----------------------
# Config
# -----------------------
ROOT = "/opt/data/private/BlackBox"
SAVE_DIR = os.path.join(ROOT, "save", "attack")
os.makedirs(SAVE_DIR, exist_ok=True)

# Patch params
PATCH_SIDE = 300
PATCH_RATIO = 0.15
MIN_PATCH_PX = 16
SCORE_THRESH = 0.5
IOU_NMS_THRESH = 0.5
IOU_MATCH_THRESH = 0.5  # 用于计算 recall 的 IoU 阈值

# Model / dataset
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_INPUT_H, MODEL_INPUT_W = 640, 640
TARGET_CLASS_IDX = 1   # person class index (与训练一致)
FALLBACK_TO_TOP = True
FALLBACK_SCORE_THRESH = 0.2

# Data loader
BATCH_SIZE = 1
NUM_WORKERS = 4

# Patch path (adjust if needed)
PATCH_PATH = os.path.join(ROOT, "save", "demo", "final_patch.pt")

# -----------------------
# Load patch
# -----------------------
if not os.path.exists(PATCH_PATH):
    raise FileNotFoundError(f"Patch file not found: {PATCH_PATH}")

patch = torch.load(PATCH_PATH, map_location='cpu')
if patch.ndimension() == 3:
    patch = patch.unsqueeze(0)
patch = patch.float().to(DEVICE).clamp(0.0, 1.0)

# -----------------------
# Helpers
# -----------------------
def detr_boxes_to_xyxy_pixel(pred_boxes):
    pb = pred_boxes.clone()
    if pb.max() <= 1.01:
        pb[:, 0] = pb[:, 0] * MODEL_INPUT_W
        pb[:, 1] = pb[:, 1] * MODEL_INPUT_H
        pb[:, 2] = pb[:, 2] * MODEL_INPUT_W
        pb[:, 3] = pb[:, 3] * MODEL_INPUT_H
    xyxy = box_convert(pb, in_fmt='cxcywh', out_fmt='xyxy')
    return xyxy.cpu()

def paste_patch_via_mask(base_img: torch.Tensor, patch_tensor: torch.Tensor, center_xy: tuple):
    if patch_tensor.dim() == 4 and patch_tensor.shape[0] == 1:
        p = patch_tensor[0]
    elif patch_tensor.dim() == 3:
        p = patch_tensor
    else:
        raise ValueError("invalid patch shape")

    ph, pw = p.shape[1], p.shape[2]
    cx, cy = int(round(center_xy[0])), int(round(center_xy[1]))
    x0 = cx - pw // 2
    y0 = cy - ph // 2

    H, W = base_img.shape[1], base_img.shape[2]

    src_x0, src_y0 = 0, 0
    dst_x0, dst_y0 = x0, y0
    dst_x1, dst_y1 = x0 + pw, y0 + ph

    if dst_x0 < 0:
        src_x0 = -dst_x0; dst_x0 = 0
    if dst_y0 < 0:
        src_y0 = -dst_y0; dst_y0 = 0
    if dst_x1 > W:
        dst_x1 = W
    if dst_y1 > H:
        dst_y1 = H

    out_w = dst_x1 - dst_x0
    out_h = dst_y1 - dst_y0
    if out_w <= 0 or out_h <= 0:
        return base_img.clone()

    src_x1 = src_x0 + out_w
    src_y1 = src_y0 + out_h
    p_cropped = p[:, src_y0:src_y1, src_x0:src_x1]

    mask = torch.zeros_like(base_img)
    mask[:, dst_y0:dst_y1, dst_x0:dst_x1] = 1.0

    padded_patch = torch.zeros_like(base_img)
    padded_patch[:, dst_y0:dst_y1, dst_x0:dst_x1] = p_cropped

    fused = base_img * (1.0 - mask) + padded_patch * mask
    return fused

def detect_on_image(model, img_tensor):
    with torch.no_grad():
        try:
            out = model(img_tensor)
        except Exception:
            out = model(NestedTensor(img_tensor))
    logits = out['pred_logits'][0]
    boxes = out['pred_boxes'][0]
    probs = torch.softmax(logits, dim=-1)
    return {'logits': logits, 'boxes': boxes, 'probs': probs}

def iou_xyxy(box_a, box_b):
    """
    box_a: (4,) xyxy
    box_b: (N,4) xyxy
    return IoU scalar or array
    """
    ax1, ay1, ax2, ay2 = box_a
    bx1 = box_b[:,0]; by1 = box_b[:,1]; bx2 = box_b[:,2]; by2 = box_b[:,3]

    inter_x1 = np.maximum(ax1, bx1)
    inter_y1 = np.maximum(ay1, by1)
    inter_x2 = np.minimum(ax2, bx2)
    inter_y2 = np.minimum(ay2, by2)

    inter_w = np.maximum(0.0, inter_x2 - inter_x1)
    inter_h = np.maximum(0.0, inter_y2 - inter_y1)
    inter_area = inter_w * inter_h

    area_a = max(0.0, (ax2 - ax1)) * max(0.0, (ay2 - ay1))
    area_b = (bx2 - bx1) * (by2 - by1)
    union = area_a + area_b - inter_area + 1e-12
    return inter_area / union

def extract_gt_boxes_from_targets(targets):
    """
    Try multiple common formats to extract GT boxes.
    Return tensor (K,4) in xyxy pixel coordinates on CPU, or None if cannot extract.
    Supported possibilities:
      - targets is a list of dicts (len==batchsize), each dict with 'boxes' (Tensor Nx4) in xyxy pixel or normalized cxcywh or xyxy
      - targets is a dict with 'boxes'
      - targets is Tensor directly
    """
    # if dataloader returns list/tuple per batch:
    if targets is None:
        return None

    # If targets is a list with length B and each element a dict
    if isinstance(targets, (list, tuple)) and len(targets) > 0:
        t0 = targets[0]
        if isinstance(t0, dict):
            if 'boxes' in t0:
                boxes = t0['boxes']
                if isinstance(boxes, torch.Tensor):
                    boxes = boxes.detach().cpu()
                    # try to detect format: if values in 0..1 assume normalized cxcywh or xyxy?
                    if boxes.max() <= 1.01:
                        # Many datasets store xyxy normalized; attempt to detect by shape (cxcywh vs xyxy ambiguous)
                        # If values look like cxcywh (cx <=1 && w<=1), we convert from cxcywh->xyxy via MODEL dims
                        # Heuristic: if second coordinate max <=1 as well -> assume normalized cxcywh (common)
                        # We will assume boxes in (xmin,ymin,xmax,ymax) normalized if any width > 1 after converting from cxcywh
                        # To be conservative, we attempt both heuristics:
                        # If first two columns <=1 and third/fourth <=1 -> assume normalized cxcywh (as in detr) and convert
                        if boxes.shape[-1] == 4:
                            # Try to detect cxcywh by seeing if center coords near 0.5 and widths small
                            # We'll assume cxcywh from DETR-style: convert cxcywh->xyxy
                            pb = boxes.clone()
                            pb[:,0] = pb[:,0] * MODEL_INPUT_W
                            pb[:,1] = pb[:,1] * MODEL_INPUT_H
                            pb[:,2] = pb[:,2] * MODEL_INPUT_W
                            pb[:,3] = pb[:,3] * MODEL_INPUT_H
                            xyxy = box_convert(pb, in_fmt='cxcywh', out_fmt='xyxy')
                            return xyxy.cpu()
                    else:
                        # assume boxes already in pixel coords xyxy
                        if boxes.shape[-1] == 4:
                            # If format is cxcywh in pixels (rare), try converting — but we assume xyxy
                            return boxes.cpu()
        # fallback: if first element is a tensor of boxes
        if isinstance(t0, torch.Tensor):
            boxes = t0.detach().cpu()
            if boxes.shape[-1] == 4:
                return boxes

    # If targets is a dict (batch-level)
    if isinstance(targets, dict):
        if 'boxes' in targets:
            boxes = targets['boxes']
            if isinstance(boxes, torch.Tensor):
                boxes = boxes.detach().cpu()
                if boxes.max() <= 1.01:
                    pb = boxes.clone()
                    pb[:,0] = pb[:,0] * MODEL_INPUT_W
                    pb[:,1] = pb[:,1] * MODEL_INPUT_H
                    pb[:,2] = pb[:,2] * MODEL_INPUT_W
                    pb[:,3] = pb[:,3] * MODEL_INPUT_H
                    xyxy = box_convert(pb, in_fmt='cxcywh', out_fmt='xyxy')
                    return xyxy.cpu()
                else:
                    return boxes.cpu()

    # Unknown format
    return None

def compute_recall(gt_boxes_np, pred_boxes_np, iou_thresh=0.5):
    """
    gt_boxes_np: (G,4) numpy xyxy
    pred_boxes_np: (P,4) numpy xyxy
    returns (tp, G)
    greedy one-to-one matching by IoU >= threshold
    """
    if gt_boxes_np is None or gt_boxes_np.shape[0] == 0:
        return 0, 0
    if pred_boxes_np is None or pred_boxes_np.shape[0] == 0:
        return 0, gt_boxes_np.shape[0]

    G = gt_boxes_np.shape[0]
    P = pred_boxes_np.shape[0]
    matched_gt = np.zeros(G, dtype=bool)
    matched_pred = np.zeros(P, dtype=bool)
    tp = 0

    # compute IoU matrix
    for pi in range(P):
        pb = pred_boxes_np[pi]
        ious = iou_xyxy(pb, gt_boxes_np)  # returns array length G
        # find best GT not yet matched
        best_idx = np.argmax(ious)
        best_iou = float(ious[best_idx])
        if best_iou >= iou_thresh and (not matched_gt[best_idx]):
            tp += 1
            matched_gt[best_idx] = True
            matched_pred[pi] = True
    return int(tp), int(G)

# -----------------------
# Data and model init
# -----------------------
dataloader = get_inria_dataloader(os.path.join(ROOT, "data", "INRIAPerson"),
                                  split="Test", batch_size=BATCH_SIZE, num_workers=NUM_WORKERS, disable_random_aug=True)
print("Test dataset size:", len(dataloader.dataset))

model = load_detr_r50().to(DEVICE)
model.eval()
for p in model.parameters():
    p.requires_grad = False

# -----------------------
# Attack evaluation loop with recall
# -----------------------
total_images = 0
sum_clean_counts = 0
sum_patched_counts = 0
sum_clean_conf = 0.0
sum_patched_conf = 0.0

total_gt_boxes = 0
total_tp_clean = 0
total_tp_patched = 0
skipped_recall_images = 0

for idx, (imgs, targets) in enumerate(dataloader):
    total_images += 1
    imgs = imgs.to(DEVICE).clamp(0, 1)
    # --- extract GT boxes (single-image batch assumed)
    gt_boxes = extract_gt_boxes_from_targets(targets)  # CPU tensor xyxy or None
    if gt_boxes is None:
        # cannot compute recall for this image
        gt_boxes_np = None
        skipped = True
        skipped_recall_images += 1
    else:
        gt_boxes_np = gt_boxes.numpy()
        skipped = False

    # --- detect clean
    clean_out = detect_on_image(model, imgs)
    logits = clean_out['logits']
    boxes = clean_out['boxes']
    probs = clean_out['probs']
    cls_scores = probs[..., TARGET_CLASS_IDX]

    if (cls_scores > SCORE_THRESH).any():
        keep_idx = (cls_scores > SCORE_THRESH).nonzero(as_tuple=False).squeeze(1)
    else:
        keep_idx = torch.tensor([], dtype=torch.long, device=cls_scores.device)
        if FALLBACK_TO_TOP:
            top_score, top_idx = torch.max(cls_scores, dim=0)
            if top_score.item() >= FALLBACK_SCORE_THRESH:
                keep_idx = top_idx.unsqueeze(0)

    if keep_idx.numel() == 0:
        sel_xyxy = torch.empty((0,4), dtype=torch.float32)
        sel_scores = torch.empty((0,), dtype=torch.float32)
    else:
        sel_boxes = boxes[keep_idx]
        sel_scores = cls_scores[keep_idx].detach().cpu()
        sel_xyxy = detr_boxes_to_xyxy_pixel(sel_boxes.detach().cpu())

        widths = (sel_xyxy[:,2] - sel_xyxy[:,0])
        heights = (sel_xyxy[:,3] - sel_xyxy[:,1])
        large_mask = (widths >= MIN_PATCH_PX) & (heights >= MIN_PATCH_PX)
        if large_mask.sum() == 0:
            sel_xyxy = torch.empty((0,4), dtype=torch.float32)
            sel_scores = torch.empty((0,), dtype=torch.float32)
        else:
            sel_xyxy = sel_xyxy[large_mask]
            sel_scores = sel_scores[large_mask]
            try:
                keep_nms = nms(sel_xyxy, sel_scores, IOU_NMS_THRESH)
            except Exception:
                keep_nms = nms(sel_xyxy.cpu(), sel_scores.cpu(), IOU_NMS_THRESH)
            sel_xyxy = sel_xyxy[keep_nms]
            sel_scores = sel_scores[keep_nms]

    clean_count = sel_xyxy.shape[0]
    avg_clean_conf = float(sel_scores.mean().item()) if sel_scores.numel() > 0 else 0.0
    sum_clean_counts += clean_count
    sum_clean_conf += avg_clean_conf

    # compute recall for clean (if gt available)
    if not skipped:
        tp_c, G = compute_recall(gt_boxes_np, sel_xyxy.numpy() if sel_xyxy.numel()>0 else np.empty((0,4)), IOU_MATCH_THRESH)
        total_gt_boxes += G
        total_tp_clean += tp_c
        recall_clean_img = (tp_c / G) if G>0 else 0.0
    else:
        recall_clean_img = None

    # --- build patched image (no EoT)
    patched = imgs.clone()
    for b_idx in range(sel_xyxy.shape[0]):
        box = sel_xyxy[b_idx]
        xmin, ymin, xmax, ymax = box.tolist()
        box_w = max(int(xmax - xmin), 1)
        box_h = max(int(ymax - ymin), 1)
        short = min(box_w, box_h)
        side = max(MIN_PATCH_PX, int(round(PATCH_RATIO * short)))
        side = max(1, side)
        patch_to_paste = patch
        patch_resized = interpolate(patch_to_paste, size=(side, side), mode='bilinear', align_corners=False)
        cx = (xmin + xmax) / 2.0
        cy = (ymin + ymax) / 2.0
        patched[0] = paste_patch_via_mask(patched[0], patch_resized.to(DEVICE), center_xy=(cx, cy))

    save_path = os.path.join(SAVE_DIR, f"patched_{idx:04d}.png")
    save_image(patched[0].detach().cpu(), save_path)

    # --- detect patched
    patched_out = detect_on_image(model, patched)
    p_logits = patched_out['logits']
    p_boxes = patched_out['boxes']
    p_probs = patched_out['probs']
    p_cls_scores = p_probs[..., TARGET_CLASS_IDX]

    if (p_cls_scores > SCORE_THRESH).any():
        p_keep_idx = (p_cls_scores > SCORE_THRESH).nonzero(as_tuple=False).squeeze(1)
    else:
        p_keep_idx = torch.tensor([], dtype=torch.long, device=p_cls_scores.device)
        if FALLBACK_TO_TOP:
            top_score, top_idx = torch.max(p_cls_scores, dim=0)
            if top_score.item() >= FALLBACK_SCORE_THRESH:
                p_keep_idx = top_idx.unsqueeze(0)

    if p_keep_idx.numel() == 0:
        p_sel_xyxy = torch.empty((0,4), dtype=torch.float32)
        p_sel_scores = torch.empty((0,), dtype=torch.float32)
    else:
        p_sel_boxes = p_boxes[p_keep_idx]
        p_sel_scores = p_cls_scores[p_keep_idx].detach().cpu()
        p_sel_xyxy = detr_boxes_to_xyxy_pixel(p_sel_boxes.detach().cpu())

        widths = (p_sel_xyxy[:,2] - p_sel_xyxy[:,0])
        heights = (p_sel_xyxy[:,3] - p_sel_xyxy[:,1])
        large_mask = (widths >= MIN_PATCH_PX) & (heights >= MIN_PATCH_PX)
        if large_mask.sum() == 0:
            p_sel_xyxy = torch.empty((0,4), dtype=torch.float32)
            p_sel_scores = torch.empty((0,), dtype=torch.float32)
        else:
            p_sel_xyxy = p_sel_xyxy[large_mask]
            p_sel_scores = p_sel_scores[large_mask]
            try:
                keep_nms2 = nms(p_sel_xyxy, p_sel_scores, IOU_NMS_THRESH)
            except Exception:
                keep_nms2 = nms(p_sel_xyxy.cpu(), p_sel_scores.cpu(), IOU_NMS_THRESH)
            p_sel_xyxy = p_sel_xyxy[keep_nms2]
            p_sel_scores = p_sel_scores[keep_nms2]

    patched_count = p_sel_xyxy.shape[0]
    avg_patched_conf = float(p_sel_scores.mean().item()) if p_sel_scores.numel() > 0 else 0.0
    sum_patched_counts += patched_count
    sum_patched_conf += avg_patched_conf

    # compute recall for patched (if gt available)
    if not skipped:
        tp_p, G_p = compute_recall(gt_boxes_np, p_sel_xyxy.numpy() if p_sel_xyxy.numel()>0 else np.empty((0,4)), IOU_MATCH_THRESH)
        # G_p should equal G (same GT count)
        total_tp_patched += tp_p
        # total_gt_boxes already incremented above for clean
        recall_patched_img = (tp_p / G) if G>0 else 0.0
    else:
        recall_patched_img = None

    # per-image print
    recall_str = f"{recall_clean_img:.3f}" if recall_clean_img is not None else "N/A"
    recall_p_str = f"{recall_patched_img:.3f}" if recall_patched_img is not None else "N/A"
    print(f"[{idx+1}/{len(dataloader)}] saved {save_path} | clean={clean_count} conf={avg_clean_conf:.3f} rec={recall_str} | patched={patched_count} conf={avg_patched_conf:.3f} rec={recall_p_str}")

# End loop: final summary
avg_clean = sum_clean_counts / max(1, total_images)
avg_patched = sum_patched_counts / max(1, total_images)
drop_abs = avg_clean - avg_patched
drop_rel = (drop_abs / avg_clean * 100.0) if avg_clean > 0 else 0.0
avg_clean_conf = sum_clean_conf / max(1, total_images)
avg_patched_conf = sum_patched_conf / max(1, total_images)

# recall summary
if total_gt_boxes > 0:
    overall_recall_clean = total_tp_clean / total_gt_boxes
    overall_recall_patched = total_tp_patched / total_gt_boxes
else:
    overall_recall_clean = None
    overall_recall_patched = None

print("\nAttack summary:")
print(f"  total_images = {total_images}")
print(f"  avg detections (clean)  = {avg_clean:.3f}")
print(f"  avg detections (patched)= {avg_patched:.3f}")
print(f"  absolute drop            = {drop_abs:.3f}")
print(f"  relative drop (%)        = {drop_rel:.2f}%")
print(f"  avg conf (clean)        = {avg_clean_conf:.3f}")
print(f"  avg conf (patched)      = {avg_patched_conf:.3f}")

if overall_recall_clean is not None:
    print(f"\n  recall (clean)   = {overall_recall_clean:.4f}  (TP={total_tp_clean}, GT={total_gt_boxes})")
    print(f"  recall (patched) = {overall_recall_patched:.4f}  (TP={total_tp_patched}, GT={total_gt_boxes})")
else:
    print("\n  recall could not be computed: GT boxes unavailable for the dataset items (extracted targets were None).")
    print(f"  skipped_recall_images = {skipped_recall_images}")
